# %%
# Importing libraries
import spacy
from spacy import displacy

# %%
# Loading model
nlp=spacy.load('en_core_web_sm')

# %%
# Defining String
text="""Switzerland, officially the Swiss Confederation, is a country situated in the confluence of Western, Central, and Southern Europe. 
It is a federal republic composed of 26 cantons, with federal authorities based in Bern. Switzerland is a landlocked country bordered by Italy to the south, France to the west,
Germany to the north, and Austria and Liechtenstein to the east. It is geographically divided among the Swiss Plateau, the Alps, and the Jura, spanning a total area of 41,285 km2, 
and land area of 39,997 km2. While the Alps occupy the greater part of the territory, the Swiss population of approximately 8.5 million is concentrated mostly on the plateau, 
where the largest cities and economic centres are located, among them Zürich, Geneva and Basel, where multiple international organisations are domiciled (such as FIFA, the UN's second-largest Office, 
and the Bank for International Settlements) and where the main international airports of Switzerland are."""

# %%
# Creating doc object
doc=nlp(text)

# %%
# Getting Named Entities
for entity in doc.ents:
  print(entity.text, '=>', entity.start_char, '=>', entity.end_char, '=>',entity.label_)
# Out:
# Switzerland => 0 => 11 => GPE
# the Swiss Confederation => 24 => 47 => ORG
# Southern Europe => 114 => 129 => LOC
# 26 => 169 => 171 => CARDINAL
# Bern => 215 => 219 => GPE
# Switzerland => 221 => 232 => GPE
# Italy => 269 => 274 => GPE
# France => 289 => 295 => GPE
# Germany => 309 => 316 => GPE
# Austria => 335 => 342 => GPE
# Liechtenstein => 347 => 360 => PERSON
# the Swiss Plateau => 409 => 426 => LOC
# Alps => 432 => 436 => LOC
# Jura => 446 => 450 => ORG
# 41,285 km2 => 477 => 487 => QUANTITY
# 39,997 km2 => 507 => 517 => QUANTITY
# Alps => 529 => 533 => LOC
# Swiss => 580 => 585 => NORP
# approximately 8.5 million => 600 => 625 => CARDINAL
# Zürich => 736 => 742 => GPE
# Geneva => 744 => 750 => GPE
# Basel => 755 => 760 => GPE
# FIFA => 828 => 832 => ORG
# UN => 838 => 840 => ORG
# second => 843 => 849 => ORDINAL
# the Bank for International Settlements => 871 => 909 => ORG
# Switzerland => 956 => 967 => GPE

# %%
# Visualizing Named Entities
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switzerland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , officially
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Swiss Confederation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is a country situated in the confluence of Western, Central, and
# ...

# %% [markdown]
# Note there are some flaws:
#
# - Liechtenstein is a place, not a person
# - Swiss Platteau is a place, not a country (should be LOC)
# - Jura is not a country (should be LOC)
#
# If data is trained on domain specific data, results may be better.

# %%
text2 = open("../data/usa.txt", "r")
txt2 = text2.read()
text2.close()
print(txt2)
# Out:
# The United States of America (USA), commonly known as the United States (U.S. or US) or America, is a country mostly located in central North America, between Canada and Mexico. It consists of 50 states, a federal district, five major self-governing territories, and various possessions. At 3.8 million square miles (9.8 million square kilometres), it is the world's third- or fourth-largest country by total area. With a population of 328 million as of 2019, it is the third most populous country in the world. The capital is Washington, D.C., and the most populous city is New York City.
#
# ...

# %%
# Creating doc object
doc2 = nlp(txt2)

# Getting Named Entities
for entity in doc2.ents:
  print(entity.text, '=>', entity.start_char, '=>', entity.end_char, '=>', entity.label_)
# Out:
# The United States of America => 0 => 28 => GPE
# USA => 30 => 33 => GPE
# the United States => 54 => 71 => GPE
# U.S. => 73 => 77 => GPE
# US => 81 => 83 => GPE
# America => 88 => 95 => GPE
# North America => 136 => 149 => LOC
# Canada => 159 => 165 => GPE
# Mexico => 170 => 176 => GPE
# 50 => 193 => 195 => CARDINAL
# five => 224 => 228 => CARDINAL
# 3.8 million square miles => 291 => 315 => QUANTITY
# 9.8 million square kilometres => 317 => 346 => QUANTITY
# third- or fourth => 367 => 383 => CARDINAL
# 328 million => 436 => 447 => CARDINAL
# 2019 => 454 => 458 => DATE
# third => 470 => 475 => ORDINAL
# Washington => 527 => 537 => GPE
# D.C. => 539 => 543 => GPE
# New York City => 575 => 588 => GPE
# Siberia => 619 => 626 => LOC
# North American => 634 => 648 => NORP
# at least 12,000 years ago => 658 => 683 => DATE
# European => 689 => 697 => NORP
# the 16th century => 720 => 736 => DATE
# The United States => 738 => 755 => GPE
# thirteen => 773 => 781 => CARDINAL
# ...

# %%
# Visualizing Named Entities
displacy.render(doc2, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The United States of America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ), commonly known as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
# ...

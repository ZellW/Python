# %% [markdown]
# ### Loading the Data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stroke_data = pd.read_csv('../data/stroke prediction.csv')
stroke_data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  30669    Male   3.0             0              0           No
# 1  30468    Male  58.0             1              0          Yes
# 2  16523  Female   8.0             0              0           No
# 3  56543  Female  70.0             0              0          Yes
# 4  46136    Male  14.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0      children          Rural              95.12  18.0              NaN
# 1       Private          Urban              87.96  39.2     never smoked
# 2       Private          Urban             110.89  17.6              NaN
# 3       Private          Rural              69.04  35.9  formerly smoked
# 4  Never_worked          Rural             161.28  19.1              NaN
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Creating Bins

# %%
bins=[0,12,19,30,60,90]
group=['child','teenager','young_adult','middle_aged', 'senior_citizen']
stroke_data['age_category']=pd.cut(stroke_data['age'], bins, labels=group)

# %%
stroke_data[['age', 'age_category']].head()
# Out:
#     age    age_category
# 0   3.0           child
# 1  58.0     middle_aged
# 2   8.0           child
# 3  70.0  senior_citizen
# 4  14.0        teenager

# %%
# Let's make the decision tree

from sklearn import tree

#seperating independent and dependent variables
y = stroke_data['stroke']
X = stroke_data[['age']]

#importing train_test_split to create validation set
from sklearn.model_selection import train_test_split

#creating the train and validation set
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 101, stratify=y, test_size=0.25)

# distribution in training set
y_train.value_counts(normalize=True)
# distribution in validation set
y_valid.value_counts(normalize=True)

#importing decision tree classifier 
from sklearn.tree import DecisionTreeClassifier
#creating the decision tree function
dt_model = DecisionTreeClassifier(random_state=10)

#fitting the model
dt_model.fit(X_train, y_train)

#fitting the model
dt_model.fit(X_train, y_train)
#checking the validation score
dt_model.score(X_valid, y_valid)

from graphviz import Digraph
decision_tree = tree.export_graphviz(dt_model, out_file = 'tree2.dot', feature_names = X_train.columns, max_depth = 2, filled = True)
# !dot -Tpng tree2.dot -o tree2.png
image = plt.imread('tree2.png')
plt.figure(figsize=(15,15))
plt.imshow(image)

# Alternative visual
#fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5,5), dpi=300)
#tree.plot_tree(dt_model, filled = True, class_names = ['No_Stroke', 'Stroke'], feature_names = ['age'])

# %% [markdown]
# The teee above is what I got.  It does not perfectly match the instructors output.  I am going to use my results in the next code block.

# %% [markdown]
# ## Binning Using Decision Tree Split

# %% [markdown]
# <img src = "decisiontreebin.png" width=600px>

# %%
bins=[0,49.5,64.5,73.5,90]
group=['Bin_1','Bin_2','Bin_3','Bin_4']
stroke_data['age_category']=pd.cut(stroke_data['age'], bins, labels=group)

# %%
stroke_data[['age', 'age_category']].head()
# Out:
#     age age_category
# 0   3.0        Bin_1
# 1  58.0        Bin_2
# 2   8.0        Bin_1
# 3  70.0        Bin_3
# 4  14.0        Bin_1

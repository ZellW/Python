# %% [markdown]
# ### Featuretools Installation

# %% [markdown]
# Before Running this notebook, you would need to install featuretools in your system.
#
# **Use the following command:**
#
# $ python -m pip install featuretools

# %%
# !python -m pip install featuretools
# Out:
# Collecting featuretools
#   Downloading featuretools-0.23.0-py3-none-any.whl (294 kB)
# Requirement already satisfied: pandas!=1.1.0,!=1.1.1,<2.0.0,>=0.24.1 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (1.1.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (1.19.3)
# Requirement already satisfied: distributed>=2.12.0 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (2.30.1)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (1.5.2)
# Requirement already satisfied: cloudpickle>=0.4.0 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (1.6.0)
# Requirement already satisfied: click>=7.0.0 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (7.1.2)
# Requirement already satisfied: tqdm>=4.32.0 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (4.50.2)
# Requirement already satisfied: pyyaml>=3.12 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (5.3.1)
# Requirement already satisfied: dask[dataframe]>=2.12.0 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (2.30.0)
# Requirement already satisfied: psutil>=5.4.8 in c:\users\czwea\anaconda3\lib\site-packages (from featuretools) (5.7.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\czwea\anaconda3\lib\site-packages (from pandas!=1.1.0,!=1.1.1,<2.0.0,>=0.24.1->featuretools) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\czwea\anaconda3\lib\site-packages (from pandas!=1.1.0,!=1.1.1,<2.0.0,>=0.24.1->featuretools) (2.8.1)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (0.11.1)
# Requirement already satisfied: setuptools in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (50.3.1.post20201107)
# Requirement already satisfied: zict>=0.1.3 in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (2.2.2)
# Requirement already satisfied: tornado>=6.0.3; python_version >= "3.8" in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (6.0.4)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\czwea\anaconda3\lib\site-packages (from distributed>=2.12.0->featuretools) (1.7.0)
# Requirement already satisfied: partd>=0.3.10; extra == "dataframe" in c:\users\czwea\anaconda3\lib\site-packages (from dask[dataframe]>=2.12.0->featuretools) (1.1.0)
# Requirement already satisfied: fsspec>=0.6.0; extra == "dataframe" in c:\users\czwea\anaconda3\lib\site-packages (from dask[dataframe]>=2.12.0->featuretools) (0.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\czwea\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.1.0,!=1.1.1,<2.0.0,>=0.24.1->featuretools) (1.15.0)
# Requirement already satisfied: heapdict in c:\users\czwea\anaconda3\lib\site-packages (from zict>=0.1.3->distributed>=2.12.0->featuretools) (1.0.1)
# Requirement already satisfied: locket in c:\users\czwea\anaconda3\lib\site-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]>=2.12.0->featuretools) (0.2.0)
# Installing collected packages: featuretools
# Successfully installed featuretools-0.23.0

# %% [markdown]
# ### Load the Dataset

# %%
import pandas as pd
import featuretools as ft

# %%
df = pd.read_csv('../data/train_bm.csv')
df.shape
# Out:
# (8523, 12)

# %%
features = df.drop('Item_Outlet_Sales', axis=1)
y = df['Item_Outlet_Sales']

# %% [markdown]
# ### Make an entityset and add the entity

# %%
es = ft.EntitySet(id = 'bigmart')
es
# Out:
# Entityset: bigmart
#   Entities:
#   Relationships:
#     No relationships

# %% [markdown]
# ### Add data to this entityset created

# %%
es.entity_from_dataframe(entity_id = 'data_1', dataframe = features, 
                         make_index = True, index = 'index')

es
# Out:
# Entityset: bigmart
#   Entities:
#     data_1 [Rows: 8523, Columns: 12]
#   Relationships:
#     No relationships

# %% [markdown]
# ### Feature Engineering

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'data_1', max_depth=1,
                                      trans_primitives = ['add_numeric', 'multiply_numeric'])

feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP + Outlet_Establishment_Year  Item_Visibility + Item_Weight  \
# index
# 0                                2248.8092                       9.316047
# 1                                2057.2692                       5.939278
# 2                                2140.6180                      17.516760
# 3                                2180.0950                      19.200000
# 4                                2040.8614                       8.930000
#
#        Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                      1999.016047
# 1                                      2009.019278
# 2                                      1999.016760
# 3                                      1998.000000
# 4                                      1987.000000
#
#        Item_Weight + Outlet_Establishment_Year  Item_MRP * Item_Visibility  \
# index
# 0                                      2008.30                    4.008763
# 1                                      2014.92                    0.930544
# 2                                      2016.50                    2.373528
# 3                                      2017.20                    0.000000
# 4                                      1995.93                    0.000000
#
#        Item_MRP * Item_Weight  Item_MRP * Outlet_Establishment_Year  \
# index
# 0                 2323.225560                           499368.5908
# 1                  285.753664                            96972.8228
# 2                 2478.315000                           283094.3820
# 3                 3496.224000                           363825.8100
# 4                  480.982302                           107022.6018
#
#        Item_Visibility * Item_Weight  \
# index
# 0                           0.149240
# 1                           0.114127
# 2                           0.293301
# 3                           0.000000
# 4                           0.000000
#
#        Item_Visibility * Outlet_Establishment_Year  \
# index
# 0                                        32.078555
# 1                                        38.729936
# 2                                        33.503390
# 3                                         0.000000
# 4                                         0.000000
#
#        Item_Weight * Outlet_Establishment_Year
# index
# 0                                     18590.70
# 1                                     11893.28
# 2                                     34982.50
# 3                                     38361.60
# 4                                     17743.91
#
# [5 rows x 23 columns]

# %%
feature_defs
# Out:
# [<Feature: Item_Identifier>,
#  <Feature: Item_Weight>,
#  <Feature: Item_Fat_Content>,
#  <Feature: Item_Visibility>,
#  <Feature: Item_Type>,
#  <Feature: Item_MRP>,
#  <Feature: Outlet_Identifier>,
#  <Feature: Outlet_Establishment_Year>,
#  <Feature: Outlet_Size>,
#  <Feature: Outlet_Location_Type>,
#  <Feature: Outlet_Type>,
#  <Feature: Item_MRP + Item_Visibility>,
#  <Feature: Item_MRP + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility>,
#  <Feature: Item_MRP * Item_Weight>,
#  <Feature: Item_MRP * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility * Item_Weight>,
#  <Feature: Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_Weight * Outlet_Establishment_Year>]

# %%
feature_matrix.shape
# Out:
# (8523, 23)

# %%
# Run deep feature synthesis with transformation primitives
feature_matrix, feature_defs = ft.dfs(entityset = es, target_entity = 'data_1', max_depth=2,
                                      trans_primitives = ['add_numeric', 'multiply_numeric'])

feature_matrix.head()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# index
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# index
# 0                      Dairy  249.8092            OUT049
# 1                Soft Drinks   48.2692            OUT018
# 2                       Meat  141.6180            OUT049
# 3      Fruits and Vegetables  182.0950            OUT010
# 4                  Household   53.8614            OUT013
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  ...  \
# index                                                              ...
# 0                           1999      Medium               Tier 1  ...
# 1                           2009      Medium               Tier 3  ...
# 2                           1999      Medium               Tier 1  ...
# 3                           1998         NaN               Tier 3  ...
# 4                           1987        High               Tier 3  ...
#
#       Item_MRP + Outlet_Establishment_Year  Item_Visibility + Item_Weight  \
# index
# 0                                2248.8092                       9.316047
# 1                                2057.2692                       5.939278
# 2                                2140.6180                      17.516760
# 3                                2180.0950                      19.200000
# 4                                2040.8614                       8.930000
#
#        Item_Visibility + Outlet_Establishment_Year  \
# index
# 0                                      1999.016047
# 1                                      2009.019278
# 2                                      1999.016760
# 3                                      1998.000000
# 4                                      1987.000000
#
#        Item_Weight + Outlet_Establishment_Year  Item_MRP * Item_Visibility  \
# index
# 0                                      2008.30                    4.008763
# 1                                      2014.92                    0.930544
# 2                                      2016.50                    2.373528
# 3                                      2017.20                    0.000000
# 4                                      1995.93                    0.000000
#
#        Item_MRP * Item_Weight  Item_MRP * Outlet_Establishment_Year  \
# index
# 0                 2323.225560                           499368.5908
# 1                  285.753664                            96972.8228
# 2                 2478.315000                           283094.3820
# 3                 3496.224000                           363825.8100
# 4                  480.982302                           107022.6018
#
#        Item_Visibility * Item_Weight  \
# index
# 0                           0.149240
# 1                           0.114127
# 2                           0.293301
# 3                           0.000000
# 4                           0.000000
#
#        Item_Visibility * Outlet_Establishment_Year  \
# index
# 0                                        32.078555
# 1                                        38.729936
# 2                                        33.503390
# 3                                         0.000000
# 4                                         0.000000
#
#        Item_Weight * Outlet_Establishment_Year
# index
# 0                                     18590.70
# 1                                     11893.28
# 2                                     34982.50
# 3                                     38361.60
# 4                                     17743.91
#
# [5 rows x 23 columns]

# %%
feature_defs
# Out:
# [<Feature: Item_Identifier>,
#  <Feature: Item_Weight>,
#  <Feature: Item_Fat_Content>,
#  <Feature: Item_Visibility>,
#  <Feature: Item_Type>,
#  <Feature: Item_MRP>,
#  <Feature: Outlet_Identifier>,
#  <Feature: Outlet_Establishment_Year>,
#  <Feature: Outlet_Size>,
#  <Feature: Outlet_Location_Type>,
#  <Feature: Outlet_Type>,
#  <Feature: Item_MRP + Item_Visibility>,
#  <Feature: Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility>,
#  <Feature: Item_Visibility * Item_Weight>,
#  <Feature: Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Weight>,
#  <Feature: Item_MRP * Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_MRP + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Weight>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Weight>,
#  <Feature: Item_MRP + Item_Weight * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_Weight>,
#  <Feature: Item_MRP + Item_Visibility * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility>,
#  <Feature: Item_MRP + Item_Visibility * Item_MRP + Item_Weight>,
#  <Feature: Item_Visibility * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_MRP + Item_Visibility>,
#  <Feature: Item_MRP * Item_MRP + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility + Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Weight * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Weight + Outlet_Establishment_Year>,
#  <Feature: Item_MRP * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Outlet_Establishment_Year * Item_Weight>,
#  <Feature: Item_Visibility + Outlet_Establishment_Year * Item_Weight>,
#  <Feature: Item_Weight + Outlet_Establishment_Year * Outlet_Establishment_Year>,
#  <Feature: Item_Visibility * Item_Visibility + Outlet_Establishment_Year>,
#  <Feature: Item_MRP + Item_Visibility * Item_Visibility + Item_Weight>,
#  <Feature: Item_Visibility * Item_Visibility + Item_Weight>,
#  <Feature: Item_MRP + Item_Weight * Item_Visibility + Item_Weight>]

# %% [markdown]
# # Web Traffic Forecasting
#
# (This notebook will help you understand how to formulate and build a deep learning model for time series data.)
#
#
# ## Understanding the Problem Statement
# In order to dynamically manage resources to run your website, you need to have an idea about the number of visitors who might arrive at your website at different points in time. So, the problem at hand is to predict the web traffic or number of sessions in the next hour based on the historical data.
#
# ## Load Dataset
#
# Let us load the dataset first.

# %%
import pandas as pd
import numpy as np

data=pd.read_csv('webtraffic.csv')

# %% [markdown]
# Check the shape of the data

# %%
data.shape
# Out:
# (4896, 2)

# %% [markdown]
# Take a glance at the first 5 rows

# %%
data.head()
# Out:
#    Hour Index    Sessions
# 0           0  1418159421
# 1           1  1113769116
# 2           2   919158921
# 3           3   822352824
# 4           4   735526737

# %% [markdown]
# ## Data Exploration

# %%
import matplotlib.pyplot as plt
sessions = data['Sessions'].values

ar = np.arange(len(sessions))
plt.figure(figsize=(22,10))
plt.plot(ar, sessions,'r')
plt.show()

# %%
#first week web traffic
sample = sessions[:168]
ar = np.arange(len(sample))
plt.figure(figsize=(22,10))
plt.plot(ar, sample,'r')
plt.show()

# %% [markdown]
# ## Data Preparation
#
# We will model the problem to predict the traffic for the next hour based on the previous week data i.e. 168 hours. Lets define a function to prepare the input and output data accordingly.
#
# *Note: The input is a sequence of values and the output is a single value.*

# %%
from IPython.display import Image
Image(filename='time1.png')

# %%
Image(filename='time2.png')

# %% [markdown]
# NOTE: The target labels are prepared using training data itself, by sequencing the data.

# %%
def prepare_data(seq,num):
  x=[]
  y=[]

  for i in range(0,(len(seq)-num),1):
    
    input_ = seq[i:i+num]
    output  = seq[i+num]
    
    x.append(input_)
    y.append(output)
    
  return np.array(x), np.array(y)

# %% [markdown]
# Call the function

# %%
num=168
x,y= prepare_data(sessions,num)

# %%
print(len(x))
# Out:
# 4728

# %% [markdown]
# No. of input sequences is around 4700

# %%
x[0]
# Out:
# array([1418159421, 1113769116,  919158921,  822352824,  735526737,
#         798400800,  895206897, 1246503249, 1355285358, 1836321840,
#        2435122440, 2925140931, 3321347328, 3266457273, 3869249877,
#        3772443780, 3701585709, 3653681661, 3480029487, 3783421791,
#        3806375814, 3212565219, 3012965019, 3007975014, 2532926538,
#        2117758122, 1775443779, 1396203399, 1150695153, 1159677162,
#        1416163419, 1772449776, 2063866068, 2357278362, 2974042980,
#        3846295854, 3630727638, 3298393305, 3475039482, 3413163420,
#        3071847078, 3003983010, 3028933035, 2388216393, 3119751126,
#        2833324839, 2424144429, 2579832585, 2257478262, 1890213894,
#        1664665668, 1275445278, 1051893054, 1044907047, 1150695153,
#        1500993504, 1691611695, 2081830086, 2642706648, 3680627688,
#        3523941531, 3053883060, 3463063470, 3274441281, 3149691156,
#        2983024989, 3002985009, 3152685159, 2971048977, 2636718642,
#        2554882560, 2395202400, 2108776113, 1759475763, 1375245378,
#        1006983009,  929138931,  855286857, 1022951025, 1300395303,
#        1502989506, 1868257872, 2600790606, 3160669167, 3548891556,
#        2954082960, 3234521241, 3254481261, 2835320841, 2915160921,
#        2859272865, 2764462770, 2481030486, 2287418292, 2131730136,
#        2000992005, 1675643679, 1322351325, 1122751125,  940116942,
#         770456772,  848300850,  970056972, 1341313344, 1521951525,
#        1985023989, 2710570716, 3103783110, 3160669167, 2809372815,
#        3081827088, 3011967018, 2726538732, 2556878562, 2644702650,
#        2429134434, 2188616193, 2143706148, 2047898052, 1860273864,
#        1640713644, 1290415293, 1118759121,  902192904,  723550725,
#         654688656,  736524738,  879238881, 1045905048, 1247501250,
#        1425145428, 1595803599, 1661671665, 1450095453, 1531931535,
#        1376243379, 1338319341, 1357281360, 1390215393, 1642709646,
#        1622749626, 1429137432, 1340315343, 1492011495, 1313369316,
#         990016992,  914168916,  851294853,  683630685,  692612694,
#         756484758,  940116942, 1252491255, 1351293354, 1315365318,
#        1481033484, 1585823589, 1515963519, 1402191405, 1380235383,
#        1492011495, 1618757622, 1631731635, 1732529736, 1797399801,
#        1712569716, 1721551725, 1650693654], dtype=int64)

# %%
y[0]
# Out:
# 1427141430

# %% [markdown]
# Split the dataset into training and validation data - maintain the order is important.  Cannot randomize!

# %%
ind = int(0.9 * len(x))

x_tr = x[:ind]
y_tr = y[:ind]

x_val=x[ind:]
y_val=y[ind:]

# %% [markdown]
# Normalize the input and output data as it speeds up the training process

# %%
from sklearn.preprocessing import StandardScaler

#normalize the inputs
x_scaler= StandardScaler()
x_tr = x_scaler.fit_transform(x_tr)
x_val= x_scaler.transform(x_val)

#reshaping the output for normalization
y_tr=y_tr.reshape(len(y_tr),1)
y_val=y_val.reshape(len(y_val),1)

#normalize the output
y_scaler=StandardScaler()
y_tr = y_scaler.fit_transform(y_tr)[:,0]
y_val = y_scaler.transform(y_val)[:,0]

# %%
print(x_tr.shape)
# Out:
# (4255, 168)

# %% [markdown]
# As you can see here, the input data is a 2 dimenional array but the LSTM and Conv1D accepts only 3 dimensional inputs in the form of (no. of samples, no. of timesteps, no. of features)
#
# So, reshaping the input data as per the model requirement

# %%
Image(filename='3Dimensions.png')

# %% [markdown]
# In this case, the length of featurtes are real number values so the feature length is 1.

# %%
#reshaping input data
x_tr= x_tr.reshape(x_tr.shape[0],x_tr.shape[1],1)
x_val= x_val.reshape(x_val.shape[0],x_val.shape[1],1)

# %%
print(x_tr.shape)
# Out:
# (4255, 168, 1)

# %% [markdown]
# Now, the data is ready for model training.
#
# <br>
#
# ## Model Building
#
# Define the model architecture

# %%
from keras.models import *
from keras.layers import *
from keras.callbacks import *

# define model
model =  Sequential()
model.add(LSTM(128,input_shape=(168,1))) # single later with input layer 168 (1 week of time)
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='linear')) # we are predicting continuous values - it is regression

# %% [markdown]
# Understand the output shape and no. of parameters of each layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               66560
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 74,881
# Trainable params: 74,881
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Define the optimizer and loss:

# %%
model.compile(loss='mse',optimizer='adam')

# %% [markdown]
# Define the callback to save the best model during the training

# %%
mc = ModelCheckpoint('../../../../../LargeData/Analytics_Vidhya/best_model_traffic.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# Train the model for 30 epochs with batch size of 32:

# %%
history=model.fit(x_tr, y_tr ,epochs=30, batch_size=32, validation_data=(x_val,y_val), callbacks=[mc])
# Out:
# Epoch 1/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0439
# Epoch 00001: val_loss improved from inf to 0.04774, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 12s 90ms/step - loss: 0.0439 - val_loss: 0.0477
# Epoch 2/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 00002: val_loss improved from 0.04774 to 0.03163, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 12s 91ms/step - loss: 0.0387 - val_loss: 0.0316
# Epoch 3/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 00003: val_loss improved from 0.03163 to 0.02419, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 12s 91ms/step - loss: 0.0350 - val_loss: 0.0242
# Epoch 4/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 00004: val_loss did not improve from 0.02419
# 133/133 [==============================] - 12s 92ms/step - loss: 0.0302 - val_loss: 0.0247
# Epoch 5/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 00005: val_loss improved from 0.02419 to 0.02293, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 15s 114ms/step - loss: 0.0306 - val_loss: 0.0229
# Epoch 6/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 00006: val_loss did not improve from 0.02293
# 133/133 [==============================] - 15s 114ms/step - loss: 0.0279 - val_loss: 0.0233
# Epoch 7/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 00007: val_loss improved from 0.02293 to 0.02249, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 20s 149ms/step - loss: 0.0275 - val_loss: 0.0225
# Epoch 8/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 00008: val_loss did not improve from 0.02249
# 133/133 [==============================] - 19s 145ms/step - loss: 0.0275 - val_loss: 0.0245
# Epoch 9/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 00009: val_loss improved from 0.02249 to 0.02097, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 21s 157ms/step - loss: 0.0246 - val_loss: 0.0210
# Epoch 10/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 00010: val_loss did not improve from 0.02097
# 133/133 [==============================] - 20s 153ms/step - loss: 0.0245 - val_loss: 0.0265
# Epoch 11/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0243
# Epoch 00011: val_loss improved from 0.02097 to 0.01930, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 17s 130ms/step - loss: 0.0243 - val_loss: 0.0193
# Epoch 12/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0232
# Epoch 00012: val_loss did not improve from 0.01930
# 133/133 [==============================] - 15s 109ms/step - loss: 0.0232 - val_loss: 0.0202
# Epoch 13/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0213
# Epoch 00013: val_loss improved from 0.01930 to 0.01848, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 16s 121ms/step - loss: 0.0213 - val_loss: 0.0185
# Epoch 14/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 00014: val_loss did not improve from 0.01848
# 133/133 [==============================] - 15s 113ms/step - loss: 0.0201 - val_loss: 0.0205
# Epoch 15/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 00015: val_loss did not improve from 0.01848
# 133/133 [==============================] - 15s 113ms/step - loss: 0.0179 - val_loss: 0.0185
# Epoch 16/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 00016: val_loss improved from 0.01848 to 0.01614, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 16s 123ms/step - loss: 0.0177 - val_loss: 0.0161
# Epoch 17/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 00017: val_loss did not improve from 0.01614
# 133/133 [==============================] - 16s 118ms/step - loss: 0.0171 - val_loss: 0.0188
# Epoch 18/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 00018: val_loss did not improve from 0.01614
# 133/133 [==============================] - 16s 123ms/step - loss: 0.0168 - val_loss: 0.0177
# Epoch 19/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 00019: val_loss did not improve from 0.01614
# 133/133 [==============================] - 16s 122ms/step - loss: 0.0163 - val_loss: 0.0202
# Epoch 20/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 00020: val_loss did not improve from 0.01614
# 133/133 [==============================] - 16s 117ms/step - loss: 0.0165 - val_loss: 0.0176
# Epoch 21/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 00021: val_loss did not improve from 0.01614
# 133/133 [==============================] - 16s 121ms/step - loss: 0.0167 - val_loss: 0.0183
# Epoch 22/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 00022: val_loss did not improve from 0.01614
# 133/133 [==============================] - 17s 130ms/step - loss: 0.0165 - val_loss: 0.0180
# Epoch 23/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 00023: val_loss did not improve from 0.01614
# 133/133 [==============================] - 15s 110ms/step - loss: 0.0156 - val_loss: 0.0183
# Epoch 24/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0154
# Epoch 00024: val_loss did not improve from 0.01614
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0154 - val_loss: 0.0177
# Epoch 25/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 00025: val_loss did not improve from 0.01614
# 133/133 [==============================] - 15s 110ms/step - loss: 0.0162 - val_loss: 0.0192
# Epoch 26/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 00026: val_loss improved from 0.01614 to 0.01564, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 16s 117ms/step - loss: 0.0162 - val_loss: 0.0156
# Epoch 27/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 00027: val_loss did not improve from 0.01564
# 133/133 [==============================] - 15s 112ms/step - loss: 0.0152 - val_loss: 0.0199
# Epoch 28/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 00028: val_loss did not improve from 0.01564
# 133/133 [==============================] - 15s 116ms/step - loss: 0.0164 - val_loss: 0.0165
# Epoch 29/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 00029: val_loss improved from 0.01564 to 0.01552, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_traffic.hdf5
# 133/133 [==============================] - 18s 137ms/step - loss: 0.0161 - val_loss: 0.0155
# Epoch 30/30
# 133/133 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 00030: val_loss did not improve from 0.01552
# 133/133 [==============================] - 17s 129ms/step - loss: 0.0150 - val_loss: 0.0167

# %% [markdown]
# Load the weights of best model prior to predictions

# %%
model.load_weights('../../../../../LargeData/Analytics_Vidhya/best_model_traffic.hdf5')

# %% [markdown]
# Evaluate the performance of model on the validation data

# %%
mse = model.evaluate(x_val,y_val)
print("Mean Square Error:",mse)
# Out:
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0155
# Mean Square Error: 0.015524770133197308

# %% [markdown]
# ## Comparision with the baseline model

# %%
#build a simple model
def compute_moving_average(data):
  pred=[]
  for i in data:
    avg=np.sum(i)/len(i)
    pred.append(avg)
  return np.array(pred)

# %%
x_reshaped = x_val.reshape(-1,168)
y_pred = compute_moving_average(x_reshaped)

# %%
mse = np.sum ( (y_val - y_pred) **2 ) / (len(y_val))
print(mse)
# Out:
# 0.5546025834434455

# %% [markdown]
# The baseline model has an mse of 0.555 vs 0.015!

# %% [markdown]
# ## Forecasting
#
# **Steps to Follow**:
#
# 1. Intialize the array, say "data" with a weeks data
# 2. Predict for the next hour
# 3. Append the predicted value as the last element of array "data"
# 4. Skip the first element of array "data"
# 5. Repeat steps 2 to 4 for **N** iterations
#
# Define a function which forecasts the traffic for the next hours from the previous week data.

# %%
def forecast(x_val, no_of_pred, ind):
  predictions=[]

  #intialize the array with previous weeks data  
  temp=x_val[ind]

  for i in range(no_of_pred): 

    #predict for the next hour
    pred=model.predict(temp.reshape(1,-1,1))[0][0]
    
    #append the prediction as the last element of array
    temp = np.insert(temp,len(temp),pred)
    predictions.append(pred)

    #ignore the first element of array
    temp = temp[1:]

  return predictions

# %% [markdown]
# Its time to forecast the traffic for the next 24 hours based on the previous week data

# %%
no_of_pred =24
ind=72
y_pred= forecast(x_val,no_of_pred,ind)

# %%
y_true = y_val[ind:ind+(no_of_pred)]

# %% [markdown]
# Lets convert back the normalized values to the original dimensional space

# %%
y_true= y_scaler.inverse_transform(y_true)
y_pred= y_scaler.inverse_transform(y_pred)

# %%
def plot(y_true,y_pred):
  ar = np.arange(len(y_true))
  plt.figure(figsize=(22,10))
  plt.plot(ar, y_true,'r')
  plt.plot(ar, y_pred,'y')
  plt.show()

# %%
plot(y_true,y_pred)

# %% [markdown]
# Wow, Thats Amazing. The forecasted values are almost close to the actual values.

# %% [markdown]
# ## How to improve the Model Performance?
#
# 1. We can make the time series data stationary
# 2. Try different number of hidden units
# 3. Change the learning rate
#
# Here is a good reference:  https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/

# %% [markdown]
# # Overview
#
# By the end of this notebook, you will understand how to-
#
# * Work with the audio data
# * Represent an audio data - Time Domain and Spectrogram
# * Build a deep learning model while working with audio data
#
# <br>
#
# # Understanding the Problem Statement
#
# According to the National Crime Records Bureau, nearly 24,012 people die each day due to a delay in getting medical assistance. Many accident victims wait for help at the site, and a delay costs them their lives. The reasons could range from ambulances stuck in traffic to the fire brigade not being able to reach the site on time due to traffic jams.
#
# The solution to the above problem is to create a system that automatically detects the emergency vehicle prior to reaching the traffic signals and change the traffic signals accordingly.
#
# <br>
#
# # Dataset
#
# Download the dataset from [here](https://drive.google.com/file/d/1VBI_X6GyYvf8j3T70-_hVDyhR_sUzeCr/view?usp=sharing)
#
# <br>
#
# ## Import Libraries
#
# Let us first import the libraries into our environment
#
# * **Librosa** is an open source library in Python that is used for audio and music analyis
#
# * **Scipy** is a python library for scientific & technical computing. It contains modules for signal processing, image processing, and linear algebera

# %%
# For audio processing
import librosa
import scipy

# %%
librosa.__version__
# Out:
# '0.8.0'

# %%
scipy.__version__
# Out:
# '1.6.1'

# %%
# For playing audio
import IPython.display as ipd

# For array processing
import numpy as np

# For visualization 
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Audio Data

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# extract data
# !unzip '/content/drive/My Drive/Course_Notes/Applied DL - Sequence Models/Project 3: Audio Classification/audio.zip'

# %%
# import emergency vehicle data
path='../../../../../LargeData/Analytics_Vidhya/emergency.wav'
emergency,sample_rate = librosa.load(path, sr = 16000)

# import non-emergency vehicle data
path='../../../../../LargeData/Analytics_Vidhya/non emergency.wav'
non_emergency,sample_rate = librosa.load(path, sr =16000)

# %% [markdown]
# We have used the sampling rate (sr) of 16000 to read the above audio data. An audio wave of 2 seconds with a sampling rate of 16,000 will have 32,000 samples.

# %% [markdown]
# __Find the duration of the audio clips__

# %%
duration1 = librosa.get_duration(emergency,sr=16000)
duration2 = librosa.get_duration(non_emergency,sr=16000)

print("Duration of an emergency and Non Emergency (in min):",duration1/60,duration2/60)
# Out:
# Duration of an emergency and Non Emergency (in min): 22.920290625 27.160834375

# %% [markdown]
# ## Preparing Data
#
# Let us break the audio into chunks of 2 seconds. So, let us define the function for the same task

# %%
from IPython.display import Image
Image(filename='audio1.png')

# %%
Image(filename='audio2.png')

# %%
def prepare_data(audio_data, num_of_samples=32000, sr=16000):
  
  data=[]
  for offset in range(0, len(audio_data), sr):
    start = offset
    end   = offset + num_of_samples
    chunk = audio_data[start:end]
    
    if(len(chunk)==32000):
      data.append(chunk)
    
  return data

# %% [markdown]
# Call the above function

# %%
# prepare audio chunks
emergency = prepare_data(emergency)
non_emergency = prepare_data(non_emergency)

# %%
print("No. of Chunks of Emergency and Non Emergency:",len(emergency),len(non_emergency))
# Out:
# No. of Chunks of Emergency and Non Emergency: 1374 1628

# %% [markdown]
# Lets listen to some of the clips

# %%
ipd.Audio(emergency[136],rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(non_emergency[10],rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Visualization of Audio Data
#
# Let's visualize the audio wave in time domain

# %%
plt.figure(figsize=(14,4))
plt.plot(np.linspace(0, 2, num=32000),emergency[103])
plt.title('Emergency')
plt.xlabel('Time')
plt.ylabel('Amplitude')

plt.figure(figsize=(14,4))
plt.plot(np.linspace(0, 2, num=32000),non_emergency[102])
plt.title('Non Emergency')
plt.xlabel('Time')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %% [markdown]
# __Combine Emergecy and Non Emergency chunks__

# %%
audio = np.concatenate([emergency,non_emergency])

# %%
# assign labels 
labels1 = np.zeros(len(emergency))
labels2 = np.ones(len(non_emergency))

# concatenate labels
labels = np.concatenate([labels1,labels2])

# %% [markdown]
# Take a glance at the shape of the combined data.

# %%
print(audio.shape)
# Out:
# (3002, 32000)

# %% [markdown]
# **Split into train and validation set**
#
# Next, we will train the model on 90% of the data and validate on the remaining 10%:

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(audio),np.array(labels),
                                            stratify=labels,test_size = 0.1,
                                            random_state=777,shuffle=True)

# %%
x_tr.shape, x_val.shape
# Out:
# ((2701, 32000), (301, 32000))

# %% [markdown]
# The input must be 3 dimensional array - (no. of examples, timesteps, features)
#
# So, lets reshape our input array according to the required shape

# %%
x_tr_features  = x_tr.reshape(len(x_tr),-1,1)
x_val_features = x_val.reshape(len(x_val),-1,1)

print("Reshaped Array Size",x_tr_features.shape)
# Out:
# Reshaped Array Size (2701, 32000, 1)

# %% [markdown]
# ## Model Architecture
#
# Let's define the model architecture using CNN conv1D layers  and the time domain features using the functional API.

# %%
from keras.layers import Input, Conv1D, Dropout, MaxPooling1D, GlobalMaxPool1D, Dense
from keras.models import Model
from keras.callbacks import ModelCheckpoint

# CNN based deep learning model architecture
def conv_model(x_tr):
  
  inputs = Input(shape=(x_tr.shape[1],x_tr.shape[2]))

  #First Conv1D layer
  conv = Conv1D(8, 13, padding='same', activation='relu')(inputs) # 8 filters and the height is 13
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)

  #Second Conv1D layer
  conv = Conv1D(16, 11, padding='same', activation='relu')(conv)
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)

  # Global MaxPooling 1D
  conv = GlobalMaxPool1D()(conv)

  #Dense Layer 
  conv = Dense(16, activation='relu')(conv)
  outputs = Dense(1, activation='sigmoid')(conv)

  model = Model(inputs, outputs)
  
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
  model_checkpoint = ModelCheckpoint('../../../../../LargeData/Analytics_Vidhya/best_model_audio_cnn.hdf5', 
                                     monitor='val_loss', verbose=1, save_best_only=True, mode='min')
  # using accuracy since the proportions are approx the same

  return model, model_checkpoint

# %% [markdown]
# __Call the model__

# %%
model, model_checkpoint = conv_model(x_tr_features)

# %% [markdown]
# Understand the shape and parameters at each layer

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32000, 1)]        0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 32000, 8)          112
# _________________________________________________________________
# dropout (Dropout)            (None, 32000, 8)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 16000, 8)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16000, 16)         1424
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16000, 16)         0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8000, 16)          0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,825
# Trainable params: 1,825
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Lets train the model for 10 epochs:

# %%
# model training
history = model.fit(x_tr_features, y_tr ,epochs=10, 
                    callbacks=[model_checkpoint], batch_size=32, 
                    validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6263 - acc: 0.7031
# Epoch 00001: val_loss improved from inf to 0.60283, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 28s 329ms/step - loss: 0.6263 - acc: 0.7031 - val_loss: 0.6028 - val_acc: 0.7973
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4832 - acc: 0.8204
# Epoch 00002: val_loss improved from 0.60283 to 0.51133, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 30s 355ms/step - loss: 0.4832 - acc: 0.8204 - val_loss: 0.5113 - val_acc: 0.8372
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4065 - acc: 0.8467
# Epoch 00003: val_loss improved from 0.51133 to 0.44972, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 32s 375ms/step - loss: 0.4065 - acc: 0.8467 - val_loss: 0.4497 - val_acc: 0.8272
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3572 - acc: 0.8541
# Epoch 00004: val_loss improved from 0.44972 to 0.41663, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 36s 429ms/step - loss: 0.3572 - acc: 0.8541 - val_loss: 0.4166 - val_acc: 0.8405
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3410 - acc: 0.8593
# Epoch 00005: val_loss improved from 0.41663 to 0.38225, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 38s 445ms/step - loss: 0.3410 - acc: 0.8593 - val_loss: 0.3823 - val_acc: 0.8638
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3300 - acc: 0.8686
# Epoch 00006: val_loss improved from 0.38225 to 0.37393, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 42s 491ms/step - loss: 0.3300 - acc: 0.8686 - val_loss: 0.3739 - val_acc: 0.8638
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3294 - acc: 0.8667
# Epoch 00007: val_loss did not improve from 0.37393
# 85/85 [==============================] - 38s 444ms/step - loss: 0.3294 - acc: 0.8667 - val_loss: 0.3802 - val_acc: 0.8405
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3224 - acc: 0.8663
# Epoch 00008: val_loss improved from 0.37393 to 0.37062, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 40s 475ms/step - loss: 0.3224 - acc: 0.8663 - val_loss: 0.3706 - val_acc: 0.8538
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3145 - acc: 0.8686
# Epoch 00009: val_loss improved from 0.37062 to 0.35943, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 41s 478ms/step - loss: 0.3145 - acc: 0.8686 - val_loss: 0.3594 - val_acc: 0.8671
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3102 - acc: 0.8719
# Epoch 00010: val_loss improved from 0.35943 to 0.35771, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn.hdf5
# 85/85 [==============================] - 42s 496ms/step - loss: 0.3102 - acc: 0.8719 - val_loss: 0.3577 - val_acc: 0.8804

# %%
# load the best model weights
model.load_weights('../../../../../LargeData/Analytics_Vidhya/best_model_audio_cnn.hdf5')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Evaluate the model on hold out set

# %%
# check model's performance on the validation set
_, acc = model.evaluate(x_val_features,y_val)
print("Validation Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 47ms/step - loss: 0.3577 - acc: 0.8804
# Validation Accuracy: 0.880398690700531

# %% [markdown]
# **Inference**
#
# Let us make predictions on the hold out set

# %%
# input audio

ind=35
test_audio = x_val[ind]
ipd.Audio(test_audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# classification
feature = x_val_features[ind]
prob = model.predict(feature.reshape(1,-1,1))
if (prob[0][0] < 0.5):
  pred='emergency'
else:
  pred='non emergency' 

print("Prediction:", pred)
# Out:
# Prediction: emergency

# %% [markdown]
# <br>
#
# Let's define the model architecture using LSTM layers and the time domain features.
#
# Recall our data size.  There are 32k records - timestamps.  Training would be very slow.  Vanishing gradient might also be a problem.

# %%
Image(filename='datasize.png')

# %% [markdown]
# To overcme this problem employ a simple hack.
#
# Instead of keeping the 3rd dimension as 1, set it at a higher number like 160.  This reduced the timestamps from 32k to just 200

# %%
# reshape chunks
x_tr_features  = x_tr.reshape(len(x_tr), -1, 160)
x_val_features = x_val.reshape(len(x_val), -1, 160)

print("Reshaped Array Size", x_tr_features.shape)
# Out:
# Reshaped Array Size (2701, 200, 160)

# %%
from keras.layers import LSTM

# LSTM based deep learning model architecture
def lstm_model(x_tr):
  
  inputs = Input(shape=(x_tr.shape[1],x_tr.shape[2]))

  #lstm
  x = LSTM(128)(inputs)
  x = Dropout(0.3)(x)
  
  #dense
  x= Dense(64,activation='relu')(x)
  x= Dense(1,activation='sigmoid')(x)
  
  model = Model(inputs, x)

  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
  
  return model

# %%
model = lstm_model(x_tr_features)
model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 200, 160)]        0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               147968
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 156,289
# Trainable params: 156,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc = ModelCheckpoint('../../../../../LargeData/Analytics_Vidhya/best_model_audio_LSTM.hdf5', 
                     monitor = 'val_loss', verbose = 1, save_best_only = True, mode = 'min')

# %%
history = model.fit(x_tr_features, y_tr, epochs = 10, 
                  callbacks = [mc], batch_size = 32, 
                  validation_data = (x_val_features, y_val))
# Out:
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6774 - acc: 0.5905
# Epoch 00001: val_loss improved from inf to 0.67146, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_LSTM.hdf5
# 85/85 [==============================] - 12s 135ms/step - loss: 0.6774 - acc: 0.5905 - val_loss: 0.6715 - val_acc: 0.6213
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.5897 - acc: 0.6975
# Epoch 00002: val_loss improved from 0.67146 to 0.39937, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_LSTM.hdf5
# 85/85 [==============================] - 10s 119ms/step - loss: 0.5897 - acc: 0.6975 - val_loss: 0.3994 - val_acc: 0.8239
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.5469 - acc: 0.7371
# Epoch 00003: val_loss did not improve from 0.39937
# 85/85 [==============================] - 10s 117ms/step - loss: 0.5469 - acc: 0.7371 - val_loss: 0.6393 - val_acc: 0.6179
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.5998 - acc: 0.6805
# Epoch 00004: val_loss did not improve from 0.39937
# 85/85 [==============================] - 10s 120ms/step - loss: 0.5998 - acc: 0.6805 - val_loss: 0.5559 - val_acc: 0.7010
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4833 - acc: 0.7712
# Epoch 00005: val_loss did not improve from 0.39937
# 85/85 [==============================] - 12s 138ms/step - loss: 0.4833 - acc: 0.7712 - val_loss: 0.5507 - val_acc: 0.7010
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4775 - acc: 0.7697
# Epoch 00006: val_loss did not improve from 0.39937
# 85/85 [==============================] - 17s 202ms/step - loss: 0.4775 - acc: 0.7697 - val_loss: 0.4190 - val_acc: 0.8140
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3679 - acc: 0.8652
# Epoch 00007: val_loss improved from 0.39937 to 0.31025, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_LSTM.hdf5
# 85/85 [==============================] - 18s 217ms/step - loss: 0.3679 - acc: 0.8652 - val_loss: 0.3103 - val_acc: 0.8804
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3274 - acc: 0.8738
# Epoch 00008: val_loss improved from 0.31025 to 0.27909, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_LSTM.hdf5
# 85/85 [==============================] - 17s 198ms/step - loss: 0.3274 - acc: 0.8738 - val_loss: 0.2791 - val_acc: 0.9136
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3723 - acc: 0.8512
# Epoch 00009: val_loss did not improve from 0.27909
# 85/85 [==============================] - 17s 202ms/step - loss: 0.3723 - acc: 0.8512 - val_loss: 0.4108 - val_acc: 0.8439
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3528 - acc: 0.8634
# Epoch 00010: val_loss did not improve from 0.27909
# 85/85 [==============================] - 17s 204ms/step - loss: 0.3528 - acc: 0.8634 - val_loss: 0.2823 - val_acc: 0.9037

# %%
# load best model weights
model.load_weights('../../../../../LargeData/Analytics_Vidhya/best_model_audio_LSTM.hdf5')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
_,acc = model.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 37ms/step - loss: 0.2791 - acc: 0.9136
# Accuracy: 0.9136212468147278

# %% [markdown]
# The LSTM model is just a bit better than the previous model.
#
# Because the CNN model validation error reduced slowly and gradually, it might be a more robust and reliable model.

# %% [markdown]
# ## Spectrogram Features
#
# Let us define a function that computes the spectrogram. We will determine if these features improve the model performance.
#
# Before that, we need to understand how the spectrogram is computed.
#
# Spectrogram accepts the raw audio wave and then breaks it into chunks or windows and then applies FFT on each window to compute the frequencies.
#
# Coming to the parameters for computing spectrogram:
#
# * nperseg = Size of the window i.e. number of samples in each chunk
# * noverlap= Number of overlapping samples between each window

# %%
def log_specgram(audio, sample_rate, eps = 1e-10):
    nperseg  = 320
    noverlap = 160

    freqs, times, spec = scipy.signal.spectrogram(audio, fs = sample_rate, 
                                                  nperseg = nperseg, noverlap = noverlap)
    # nperseg - number of samples in an audio chunk 
    # noverlap - number of overlapping samples in an audio chunk
    # scipy.signal.spectrogram - returns 3 audio outputs.  spec is key for this exercise
    
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)
# log is used because the amplitude can be very small

# %% [markdown]
# Define a function for representing spectrogram:

# %%
def plot(spectrogram, label): # label is either emergency or non-emergency
  fig = plt.figure(figsize=(14, 8))
  ax = fig.add_subplot(211)
  ax.imshow(spectrogram.T, aspect='auto', extent=[times.min(), times.max(), freqs.min(), freqs.max()])
  ax.set_title('Spectrogram of '+label)
  ax.set_ylabel('Freqs in Hz')
  ax.set_xlabel('Seconds')

# %% [markdown]
# Compute the spectrogram:

# %%
freqs, times, spectrogram = log_specgram(emergency[300], sample_rate)
plot(spectrogram,"emergency")

freqs, times, spectrogram = log_specgram(non_emergency[300], sample_rate)
plot(spectrogram,"non emergency")

# %%
spectrogram.shape
# Out:
# (199, 161)

# %% [markdown]
# __Extract the spectrogram features__

# %%
def extract_spectrogram_features(x_tr):
  features=[]
  for i in x_tr:
    _, _, spectrogram = log_specgram(i, sample_rate)
    
    mean = np.mean(spectrogram, axis=0)
    std = np.std(spectrogram, axis=0)
    spectrogram = (spectrogram - mean) / std
    
    features.append(spectrogram)

  return np.array(features)

# %%
x_tr_features  = extract_spectrogram_features(x_tr)
x_val_features = extract_spectrogram_features(x_val)

# %% [markdown]
# __Call the LSTM Model__

# %%
model_2 = lstm_model(x_tr_features)

# %%
mc = ModelCheckpoint('../../../../../LargeData/Analytics_Vidhya/best_model_audio_spec.hdf5', 
                     monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# Understand the no. of parameters and shape of each layer:

# %%
model_2.summary()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 199, 161)]        0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               148480
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 156,801
# Trainable params: 156,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history=model_2.fit(x_tr_features, y_tr, 
                    epochs=10, callbacks=[mc], batch_size=32, 
                    validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 85/85 [==============================] - ETA: 0s - loss: 0.6393 - acc: 0.6261
# Epoch 00001: val_loss improved from inf to 0.58982, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_spec.hdf5
# 85/85 [==============================] - 11s 135ms/step - loss: 0.6393 - acc: 0.6261 - val_loss: 0.5898 - val_acc: 0.7243
# Epoch 2/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4136 - acc: 0.8249
# Epoch 00002: val_loss improved from 0.58982 to 0.30464, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_spec.hdf5
# 85/85 [==============================] - 10s 120ms/step - loss: 0.4136 - acc: 0.8249 - val_loss: 0.3046 - val_acc: 0.8870
# Epoch 3/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3178 - acc: 0.8841
# Epoch 00003: val_loss improved from 0.30464 to 0.23385, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_spec.hdf5
# 85/85 [==============================] - 10s 119ms/step - loss: 0.3178 - acc: 0.8841 - val_loss: 0.2339 - val_acc: 0.9269
# Epoch 4/10
# 85/85 [==============================] - ETA: 0s - loss: 0.2211 - acc: 0.9226
# Epoch 00004: val_loss did not improve from 0.23385
# 85/85 [==============================] - 9s 111ms/step - loss: 0.2211 - acc: 0.9226 - val_loss: 0.2731 - val_acc: 0.9003
# Epoch 5/10
# 85/85 [==============================] - ETA: 0s - loss: 0.4297 - acc: 0.8001
# Epoch 00005: val_loss did not improve from 0.23385
# 85/85 [==============================] - 10s 123ms/step - loss: 0.4297 - acc: 0.8001 - val_loss: 0.5068 - val_acc: 0.7375
# Epoch 6/10
# 85/85 [==============================] - ETA: 0s - loss: 0.3749 - acc: 0.8349
# Epoch 00006: val_loss did not improve from 0.23385
# 85/85 [==============================] - 10s 123ms/step - loss: 0.3749 - acc: 0.8349 - val_loss: 0.3333 - val_acc: 0.8738
# Epoch 7/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1862 - acc: 0.9378
# Epoch 00007: val_loss improved from 0.23385 to 0.17950, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_spec.hdf5
# 85/85 [==============================] - 15s 173ms/step - loss: 0.1862 - acc: 0.9378 - val_loss: 0.1795 - val_acc: 0.9402
# Epoch 8/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1481 - acc: 0.9474
# Epoch 00008: val_loss did not improve from 0.17950
# 85/85 [==============================] - 14s 167ms/step - loss: 0.1481 - acc: 0.9474 - val_loss: 0.2177 - val_acc: 0.9103
# Epoch 9/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1894 - acc: 0.9378
# Epoch 00009: val_loss did not improve from 0.17950
# 85/85 [==============================] - 15s 171ms/step - loss: 0.1894 - acc: 0.9378 - val_loss: 0.2507 - val_acc: 0.9103
# Epoch 10/10
# 85/85 [==============================] - ETA: 0s - loss: 0.1584 - acc: 0.9426
# Epoch 00010: val_loss did not improve from 0.17950
# 85/85 [==============================] - 15s 171ms/step - loss: 0.1584 - acc: 0.9426 - val_loss: 0.1872 - val_acc: 0.9435

# %% [markdown]
# Load the weights of the best model:

# %%
model_2.load_weights('../../../../../LargeData/Analytics_Vidhya/best_model_audio_spec.hdf5')

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# The loss curve is still unven but not as bad as the LSTM model without the spec features.
#
# Evaluating the performance of the model on validation set:

# %%
_,acc = model_2.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 38ms/step - loss: 0.1795 - acc: 0.9402
# Accuracy: 0.9401993155479431

# %% [markdown]
# Accuracy with the spec features improve model performance.

# %% [markdown]
# <br>
#
# Lets train the CNN based model on the same spectrogram features.
#
# I have copied the CNN Model function below to change the name of the saved model checkpoint file.

# %%
from keras.layers import Input, Conv1D, Dropout, MaxPooling1D, GlobalMaxPool1D, Dense
from keras.models import Model
from keras.callbacks import ModelCheckpoint

# CNN based deep learning model architecture
def conv_model(x_tr):
  
  inputs = Input(shape=(x_tr.shape[1],x_tr.shape[2]))

  #First Conv1D layer
  conv = Conv1D(8, 13, padding='same', activation='relu')(inputs) # 8 filters and the height is 13
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)

  #Second Conv1D layer
  conv = Conv1D(16, 11, padding='same', activation='relu')(conv)
  conv = Dropout(0.3)(conv)
  conv = MaxPooling1D(2)(conv)

  # Global MaxPooling 1D
  conv = GlobalMaxPool1D()(conv)

  #Dense Layer 
  conv = Dense(16, activation='relu')(conv)
  outputs = Dense(1, activation='sigmoid')(conv)

  model = Model(inputs, outputs)
  
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
  model_checkpoint = ModelCheckpoint('../../../../../LargeData/Analytics_Vidhya/best_model_audio_cnn_spec.hdf5', 
                                     monitor='val_loss', verbose=1, save_best_only=True, mode='min')
  # using accuracy since the proportions are approx the same

  return model, model_checkpoint

# %%
model_3, mc = conv_model(x_tr_features)

# %% [markdown]
# Understand the input and output shape of each layer:

# %%
model_3.summary()
# Out:
# Model: "functional_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 199, 161)]        0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 199, 8)            16752
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 199, 8)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 99, 8)             0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 99, 16)            1424
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 99, 16)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 49, 16)            0
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 18,465
# Trainable params: 18,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training the model:

# %%
history=model_3.fit(x_tr_features, y_tr, 
                    epochs=10, callbacks=[mc], batch_size=32, 
                    validation_data=(x_val_features,y_val))
# Out:
# Epoch 1/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.5515 - acc: 0.7086
# Epoch 00001: val_loss improved from inf to 0.41845, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 3s 39ms/step - loss: 0.5494 - acc: 0.7105 - val_loss: 0.4185 - val_acc: 0.8538
# Epoch 2/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.3243 - acc: 0.8577
# Epoch 00002: val_loss improved from 0.41845 to 0.29197, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 25ms/step - loss: 0.3240 - acc: 0.8575 - val_loss: 0.2920 - val_acc: 0.9103
# Epoch 3/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.2425 - acc: 0.9014
# Epoch 00003: val_loss improved from 0.29197 to 0.23927, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 23ms/step - loss: 0.2418 - acc: 0.9019 - val_loss: 0.2393 - val_acc: 0.9369
# Epoch 4/10
# 83/85 [============================>.] - ETA: 0s - loss: 0.1676 - acc: 0.9394
# Epoch 00004: val_loss improved from 0.23927 to 0.21318, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1673 - acc: 0.9400 - val_loss: 0.2132 - val_acc: 0.9435
# Epoch 5/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.1416 - acc: 0.9464
# Epoch 00005: val_loss improved from 0.21318 to 0.19651, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1419 - acc: 0.9463 - val_loss: 0.1965 - val_acc: 0.9468
# Epoch 6/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.1039 - acc: 0.9632
# Epoch 00006: val_loss improved from 0.19651 to 0.16100, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 23ms/step - loss: 0.1040 - acc: 0.9630 - val_loss: 0.1610 - val_acc: 0.9435
# Epoch 7/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0914 - acc: 0.9669
# Epoch 00007: val_loss improved from 0.16100 to 0.14343, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0912 - acc: 0.9670 - val_loss: 0.1434 - val_acc: 0.9601
# Epoch 8/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.1015 - acc: 0.9624
# Epoch 00008: val_loss improved from 0.14343 to 0.13525, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 24ms/step - loss: 0.1011 - acc: 0.9626 - val_loss: 0.1353 - val_acc: 0.9535
# Epoch 9/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0638 - acc: 0.9754
# Epoch 00009: val_loss improved from 0.13525 to 0.12051, saving model to ../../../../../LargeData/Analytics_Vidhya\best_model_audio_cnn_spec.hdf5
# 85/85 [==============================] - 2s 25ms/step - loss: 0.0637 - acc: 0.9756 - val_loss: 0.1205 - val_acc: 0.9601
# Epoch 10/10
# 84/85 [============================>.] - ETA: 0s - loss: 0.0768 - acc: 0.9721
# Epoch 00010: val_loss did not improve from 0.12051
# 85/85 [==============================] - 2s 23ms/step - loss: 0.0765 - acc: 0.9722 - val_loss: 0.1293 - val_acc: 0.9468

# %% [markdown]
# Load the best saved model

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Evaluating the performance of the model:

# %%
model_3.load_weights('../../../../../LargeData/Analytics_Vidhya/best_model_audio_cnn_spec.hdf5')

# %%
# model's performance on the validation set
_,acc = model_3.evaluate(x_val_features,y_val)
print("Accuracy:",acc)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1205 - acc: 0.9601
# Accuracy: 0.960132896900177

# %% [markdown]
# The spectrogram features helped improve the CNN model too!

# %% [markdown]
# ### What else to try?
#
# * Different model architectures
# * Use Frequency domain features
# * Change input sequence length
# * more...
